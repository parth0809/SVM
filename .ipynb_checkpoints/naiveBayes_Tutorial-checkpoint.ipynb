# %% [markdown]
# ## Assignment-2 : Naive Bayes
# ### Name: [ Your Name ]
# ### Roll: [ Your Roll number ]
# ### Section: [ Your Section ]

# %% [markdown]
# ## Set-up and Installations

# %%
# Installation requirements
# !pip install scikit-learn pandas numpy matplotlib
# !pip install seaborn

import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn modules
from sklearn.model_selection import train_test_split

# To fetch datasets from UCI repository
# !pip install ucimlrepo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/sreejitasaha/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: pandas in /home/sreejitasaha/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: numpy in /home/sreejitasaha/.local/lib/python3.10/site-packages (1.26.2)
# Requirement already satisfied: matplotlib in /home/sreejitasaha/.local/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/sreejitasaha/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=1.2 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/sreejitasaha/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ucimlrepo in /home/sreejitasaha/.local/lib/python3.10/site-packages (0.0.3)

# %% [markdown]
# ## Spambase Dataset(Odd Roll Numbers)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
spambase = fetch_ucirepo(id=94) 
  
# data (as pandas dataframes) 
X = spambase.data.features 
y = spambase.data.targets 
  
print(X.head())
print(y.head())
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 0             0.00            0.00  ...                   0.0         0.00
# 1             0.00            0.94  ...                   0.0         0.00
# 2             0.64            0.25  ...                   0.0         0.01
# 3             0.31            0.63  ...                   0.0         0.00
# 4             0.31            0.63  ...                   0.0         0.00
#
#    char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0        0.000          0.0        0.778        0.000        0.000
# 1        0.132          0.0        0.372        0.180        0.048
# 2        0.143          0.0        0.276        0.184        0.010
# 3        0.137          0.0        0.137        0.000        0.000
# 4        0.135          0.0        0.135        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total
# 0                       278
# 1                      1028
# 2                      2259
# 3                       191
# 4                       191
#
# [5 rows x 57 columns]
#    Class
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %% [markdown]
# ## Mushroom Dataset(Even Roll Numbers)

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X = mushroom.data.features 
y = mushroom.data.targets 
  
print(X.head())
print(y.head())
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# 4         b          k           t  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 22 columns]
#   poisonous
# 0         p
# 1         e
# 2         e
# 3         p
# 4         e

# %% [markdown]
# ## Pre-Processing

# %%
# Create a train-test splits(80%-20%) and handle missing values
# Your Code Here

# %% [markdown]
# ## Visualize the data

# %%
# Create histogram plots/Bar Charts(count plots) for at least three features 
# Your Code Here

# %% [markdown]
# ## Implement Naive Bayes from Scratch

# %%
class NaiveBayesClassifier:
    def __init__(self,alpha=1.0):
        # Initialize the required variables
        # Your Code Here
        pass

    def fit(self,X,y):
        # Learns the model parameters (class priors P(y) and likelihoods P(xi​∣y)) by calculating probabilities, means,
        # and variances from the training dataset.
        # Your Code Here
        pass

    def predict(self,X):
        # Uses the learned parameters from fit to calculate the posterior probability for each class on new, unseen data 
        # (Xtest​) and returns the class with the highest probability.
        # Your Code Here
        pass

# %%
# Experiment with different hyperparameter values
alpha = [0.0001,0.001,0.01,0.1,1,10]
# Your Code Here

# %% [markdown]
# ## Visualization and Hyperparameter Tuning

# %%
# Predict the y values for the test set using the best model
# Your Code Here

# %%
# Display the confusion matrix for the best performing model on the test set
# Your Code Here

# %%
# NOTE - DO NOT USE SKLEARN METRICS FUNCTIONS TO CALCULATE THE BELOW METRICS
# Calculate accuracy, recall, precision and F1 score for all alpha values
# Your Code Here

# %%
# Build a plot with alpha along the x-axis and training/test accuracy/recall/precision/F1 along the y-axis
# Your Code Here

# %% [markdown]
# #### Explain which value of ‘a’ is most suitable for your dataset and why.
# #### Discuss how this smoothing parameter influences the model and helps prevent overfitting.
#
# #### [ Your Analysis ]

# %% [markdown]
# ## Investigating the Independence Assumption

# %%
# Select one feature that you believe is highly discriminative
# Create new versions train and test datasets

# Your Code Here

# %%
# Iterative Training and Evaluation using the best hyperparameter 'a'
# Evaluate training/test accuracy/recall/precision/F1

# Dataset 1(one copy)
# Your Code Here

# %%
# Dataset 2(two copies)
# Your Code Here

# %%
# Dataset 3(three copies)
# Your Code Here

# %%
# Dataset 4(four copies)
# Your Code Here

# %% [markdown]
# ## Plot the results

# %%
# Plot both the training/test accuracy/recall/precision/F1 as a function of the number of duplicate features added
# The x-axis should be the "Number of Added Copies" (0, 1, 2, 3, 4), and the y-axis should show the accuracy/recall/precision/F1.
# Your Code Here

# %% [markdown]
# ## Discussions
# #### How does adding duplicate (and thus perfectly correlated) features affect the classifier's performance?
# #### Explain this behavior by referencing the Naive Bayes decision rule.
# #### What happens mathematically to the likelihood term when you add a copy of a feature?
#
# #### [ Your Analysis ]
